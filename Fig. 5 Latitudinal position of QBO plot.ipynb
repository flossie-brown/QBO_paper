 2.5, 1.25, 0.0, -1.25, -2.5, -2.5, -2.5, -2.5, -1.25, 1.25, 2.5, 3.75, 13.75, 0.0, 0.0, 0.0], [-2.5, -2.5, -2.5, -1.25, 0.0, 2.5, 3.75, 3.75, 3.75, 2.5, 1.25, -1.25, -2.5, -2.5, -2.5, -2.5, -1.25, 0.0, 1.25, 1.25, 2.5, 2.5, 1.25, -1.25, -2.5, -2.5, -2.5, -2.5, -1.25, 0.0, 1.25, 2.5, 2.5, 2.5, 1.25, -1.25], [-2.5, -2.5, -2.5, -1.25, 0.0, 1.25, 2.5, 3.75, 3.75, 2.5, 0.0, -1.25, -2.5, -2.5, -1.25, -1.25, -1.25, 0.0, 1.25, 1.25, 2.5, 2.5, 1.25, 0.0, -1.25, -2.5, -2.5, -1.25, 0.0, 1.25, 2.5, 2.5, 2.5, 2.5, -1.25, -1.25]]
JNWcontrol =[[2.5, 3.75, 3.75, 2.5, 1.25, 0.0, -2.5, -2.5, -2.5, -1.25, -1.25, 0.0, 1.25, 1.25, 1.25, 1.25, 0.0, 0.0, -2.5, -2.5, -2.5, -2.5, -1.25, 0.0, 1.25, 1.25, 1.25, 1.25, 0.0, -1.25, -2.5, -2.5, -2.5, -1.25, 0.0, 0.0], [2.5, 2.5, 2.5, 1.25, 0.0, -1.25, -2.5, -2.5, -2.5, -2.5, -1.25, 0.0, 0.0, 1.25, 1.25, 1.25, 0.0, 0.0, -1.25, -1.25, -1.25, 0.0, 0.0, 1.25, 2.5, 2.5, 3.75, 2.5, 1.25, 0.0, -1.25, -2.5, -1.25, 0.0, 0.0, 0.0], [2.5, 2.5, 3.75, 3.75, 1.25, 0.0, -1.25, -2.5, -1.25, -1.25, -1.25, 0.0, 1.25, 1.25, 2.5, 2.5, 1.25, -1.25, -1.25, -2.5, -2.5, -2.5, -1.25, 0.0, 1.25, 1.25, 2.5, 1.25, 0.0, -1.25, -1.25, -2.5, -2.5, 0.0, 0.0]]
JNEcontrol =[[1.25, 1.25, 2.5, 2.5, 0.0, 0.0, -1.25, -1.25, -1.25, -1.25, 0.0, 1.25, 2.5, 2.5, 2.5, 0.0, 0.0, -1.25, -2.5, -2.5, -1.25, -1.25, 0.0, 0.0, 1.25, 2.5, 3.75, 2.5, 1.25, -2.5, -2.5, -2.5, -2.5, -2.5, 0.0, 1.25], [1.25, 1.25, 1.25, 1.25, 0.0, -1.25, -1.25, -2.5, -2.5, -1.25, 0.0, 1.25, 1.25, 2.5, 2.5, 1.25, 1.25, 0.0, -2.5, -2.5, -1.25, 0.0, 0.0, 0.0, 2.5, 3.75, 5.0, 3.75, 0.0, -1.25, -2.5, -2.5, -5.0, -2.5, -2.5, -1.25], [1.25, 2.5, 2.5, 1.25, 0.0, -1.25, -2.5, -3.75, -2.5, -2.5, -1.25, 0.0, 1.25, 1.25, 2.5, 1.25, 1.25, -1.25, -1.25, -2.5, -1.25, -1.25, 0.0, 1.25, 3.75, 3.75, 6.25, 6.25, 1.25, 0.0, -1.25, -2.5, -2.5, -2.5, -1.25, 0.0]]
JLEcontrol =[[-2.5, -2.5, -2.5, -2.5, -1.25, 1.25, 2.5, 3.75, 0, 0.0, 0.0, 0.0, -2.5, -2.5, -2.5, -1.25, 0.0, 2.5, 2.5, 3.75, 3.75, 2.5, 1.25, 0.0, -2.5, -2.5, -2.5, -1.25, -1.25, 0.0, 1.25, 1.25, 1.25, 1.25, 0.0, 0.0], [-2.5, -2.5, -2.5, -1.25, 0.0, 1.25, 0.0, 1.25, 1.25, 1.25, 0.0, -1.25, -2.5, -2.5, -2.5, -1.25, 0.0, 0.0, 1.25, 2.5, 3.75, 2.5, 1.25, -1.25, -2.5, -2.5, -1.25, -1.25, 0.0, 0.0, 2.5, 2.5, 2.5, 2.5, 1.25, -1.25], [-2.5, -2.5, -2.5, -1.25, -1.25, 0.0, 1.25, 2.5, 1.25, 1.25, 0.0, -1.25, -1.25, -2.5, -2.5, -2.5, -2.5, -1.25, 0.0, 1.25, 3.75, 3.75, 1.25, -1.25, -1.25, -2.5, -2.5, -1.25, -1.25, 0.0, 1.25, 2.5, 2.5, 1.25, 1.25, -1.25]]

# %%
full_list = [JNW, JLW, JNE, JLE]

# %%
control_list = [JNWcontrol, JLWcontrol, JNEcontrol, JLEcontrol]

# %% [markdown]
# ### Design plot features

# %%
x = np.linspace(0, 36, 36)
legend_labels = ['EQ 60 Tg', '45$^\circ$N 60 Tg', '45$^\circ$S 60 Tg', 'EQ 15 Tg', '45$^\circ$N 15 Tg', '45$^\circ$S 15 Tg', 'Control 0', 'Control 1', 'Control 2']
names = ['January, w-QBO', 'July, w-QBO', 'January, e-QBO', 'July, e-QBO']
letter_labels = ['(a)', '(b)', '(c)', '(d)']

# %%
line_colours = ['blue', 'darkgoldenrod', 'red', 'cyan', 'gold', 'salmon']

# %% [markdown]
# ## Plot

# %%
fig, axs = plt.subplots(2,2, sharey = True, sharex = True, figsize = (17,15))


ax = axs.ravel()

for i, season in enumerate(full_list):
    for b, eruption in enumerate(season):
        x = range(0, 36)
        y = eruption
        ax[i].plot(x,y, color = line_colours[b], linewidth = 4)
        
    
for i, season in enumerate(control_list):
    for b, eruption in enumerate(season):
        x = range(0, len(eruption))
        y = eruption
        ax[i].plot(x, y, 'k--', linewidth = 5)
        
    ax[i].set_title('%s' % names[i], fontsize = 30, y = 1.02) 
    ax[i].set_ylim(-15,15)
    ax[i].set_xlim(0, 20)
    ax[i].xaxis.set_tick_params(width = 1.5, labelsize = 25, direction = 'out', length = 5)
    ax[i].yaxis.set_tick_params(width = 1.5, labelsize = 25, direction = 'out', length = 5)
    ax[i].set_title(letter_labels[i], size=20, loc = 'left', y = 1.07)
    ax[i].fill_between(x, y1 = 5.5, y2 = -5.5, facecolor = 'black', alpha = 0.1)
    ax[i].axhline(0, color = 'black')
    

ax[0].set_ylabel('Latitude / degrees', fontsize = 25)
ax[2].set_ylabel('Latitude / degrees', fontsize = 25)
    
ax[2].set_xlabel('Months since start of simulation', fontsize = 25)    
ax[3].set_xlabel('Months since start of simulation', fontsize = 25)    
  
plt.legend(legend_labels, prop={'size': 25},bbox_to_anchor=(-1,-0.2), loc='upper left', ncol = 3)

plt.tight_layout() 
plt.subplots_adjust( bottom = 0.2, wspace = 0.1, hspace = 0.15)
plt.savefig('QBO_lat_position.png')

# %%
legend_labels = ['Tropical 60 Tg', 'Tropical 15 Tg', 'Control 0', 'Control 1', 'Control 2']

# %%
fig, axs = plt.subplots(2,2, sharey = True, sharex = True, figsize = (17,15))


ax = axs.ravel()

for i, season in enumerate(full_list):
    for b, eruption in enumerate(season[::3]):
        x = range(0, 36)
        y = eruption
        ax[i].plot(x,y, color = line_colours[b*3], linewidth = 4)
        
    
for i, season in enumerate(control_list):
    for b, eruption in enumerate(season):
        x = range(0, len(eruption))
        y = eruption
        ax[i].plot(x, y, 'k--', linewidth = 5)
        
    ax[i].set_title('%s' % names[i], fontsize = 30, y = 1.02) 
    ax[i].set_ylim(-15,15)
    ax[i].set_xlim(0, 20)
    ax[i].xaxis.set_tick_params(width = 1.5, labelsize = 25, direction = 'out', length = 5)
    ax[i].yaxis.set_tick_params(width = 1.5, labelsize = 25, direction = 'out', length = 5)
    ax[i].set_title(letter_labels[i], size=20, loc = 'left', y = 1.07)
    ax[i].fill_between(x, y1 = 5.5, y2 = -5.5, facecolor = 'black', alpha = 0.1)
    ax[i].axhline(0, color = 'black')
    

ax[0].set_ylabel('Latitude / degrees', fontsize = 25)
ax[2].set_ylabel('Latitude / degrees', fontsize = 25)
    
ax[2].set_xlabel('Months since start of simulation', fontsize = 25)    
ax[3].set_xlabel('Months since start of simulation', fontsize = 25)    
  
plt.legend(legend_labels, prop={'size': 25},bbox_to_anchor=(-1,-0.2), loc='upper left', ncol = 3)

plt.tight_layout() 
plt.subplots_adjust( bottom = 0.2, wspace = 0.1, hspace = 0.2)
plt.savefig('QBO_lat_position_tropics.png')

# %%
cm = 1/2.54
fig, axs = plt.subplots(1,2, sharey = True, sharex = True, figsize = (21*cm,11*cm))


ax = axs.ravel()

for i, season in enumerate(full_list[1:4:2]):
    for b, eruption in enumerate(season[::3]):
        x = range(0, 36)
        y = eruption
        ax[i].plot(x,y, color = line_colours[b*3], linewidth = 2.4)
        
    
for i, season in enumerate(control_list[1:4:2]):
    for b, eruption in enumerate(season):
        x = range(0, len(eruption))
        y = eruption
        ax[i].plot(x, y, 'k--', linewidth = 3)
        
    ax[i].set_title('%s' % names[i*2+1], fontsize = 15, y = 1.02) 
    ax[i].set_ylim(-15,15)
    ax[i].set_xlim(0, 20)
    ax[i].xaxis.set_tick_params(width = 1, labelsize = 13, direction = 'out', length = 3)
    ax[i].yaxis.set_tick_params(width = 1, labelsize = 13, direction = 'out', length = 3)
    ax[i].set_title(letter_labels[i], size=13, loc = 'left', y = 1.07)
    ax[i].fill_between(x, y1 = 5.5, y2 = -5.5, facecolor = 'black', alpha = 0.1)
    ax[i].axhline(0, color = 'black')
    

ax[0].set_ylabel('Latitude / degrees', fontsize = 13)
#ax[].set_ylabel('Latitude / degrees', fontsize = 25)
    
ax[0].set_xlabel('Months since start of simulation', fontsize = 13, labelpad = 10)    
ax[1].set_xlabel('Months since start of simulation', fontsize = 13, labelpad = 10)    
  
plt.legend(legend_labels, prop={'size': 13},bbox_to_anchor=(-1,-0.3), loc='upper left', ncol = 3)

plt.tight_layout() 
plt.subplots_adjust( bottom = 0.2, wspace = 0.1, hspace = 0.2)
plt.savefig('Fig05.png', dpi = 500)

# %%
cm = 1/2.54
fig, axs = plt.subplots(1,2, sharey = True, sharex = True, figsize = (21*cm,11*cm))


ax = axs.ravel()

for i, season in enumerate(full_list[0:4:2]):
    for b, eruption in enumerate(season[::3]):
        x = range(0, 36)
        y = eruption
        ax[i].plot(x,y, color = line_colours[b*3], linewidth = 2.4)
        
    
for i, season in enumerate(control_list[0:4:2]):
    for b, eruption in enumerate(season):
        x = range(0, len(eruption))
        y = eruption
        ax[i].plot(x, y, 'k--', linewidth = 3)
        
    ax[i].set_title('%s' % names[i*2], fontsize = 15, y = 1.02) 
    ax[i].set_ylim(-15,15)
    ax[i].set_xlim(0, 20)
    ax[i].xaxis.set_tick_params(width = 1, labelsize = 13, direction = 'out', length = 3)
    ax[i].yaxis.set_tick_params(width = 1, labelsize = 13, direction = 'out', length = 3)
    ax[i].set_title(letter_labels[i], size=13, loc = 'left', y = 1.07)
    ax[i].fill_between(x, y1 = 5.5, y2 = -5.5, facecolor = 'black', alpha = 0.1)
    ax[i].axhline(0, color = 'black')
    

ax[0].set_ylabel('Latitude / degrees', fontsize = 13)
#ax[].set_ylabel('Latitude / degrees', fontsize = 25)
    
ax[0].set_xlabel('Months since start of simulation', fontsize = 13, labelpad = 10)    
ax[1].set_xlabel('Months since start of simulation', fontsize = 13, labelpad = 10)    
  
plt.legend(legend_labels, prop={'size': 13},bbox_to_anchor=(-1,-0.3), loc='upper left', ncol = 3)

plt.tight_layout() 
plt.subplots_adjust( bottom = 0.2, wspace = 0.1, hspace = 0.2)
plt.savefig('FigS2.png', dpi = 500)
